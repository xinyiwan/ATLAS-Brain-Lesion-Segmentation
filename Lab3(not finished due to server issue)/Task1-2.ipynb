# %% [markdown]
# # Task 1

# %%
from tensorflow import keras

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, SpatialDropout2D
from tensorflow.keras.optimizers import Adam, RMSprop
import matplotlib.pyplot as plt
import numpy as np

# %%
import os

from random import shuffle
from skimage.io import imread
from skimage.transform import resize


def gen_labels(im_name, class_list):
    '''

    Parameters
    ----------
    im_name : Str
        The image file name.
    pat1 : Str
        A string pattern in the filename for 1st class, e.g "Mel"
    pat2 : Str
        A string pattern in the filename 2nd class, e.g, "Nev"

    Returns
    -------
    Label : Numpy array
        Class label of the filename name based on its pattern.
    '''
    label = [class_idx for class_idx,class_name in enumerate(class_list) if class_name in im_name]
    return label[0]


def get_data(data_path, data_list, img_h, img_w, class_list):
    """

    Parameters
    ----------
    train_data_path : Str
        Path to the data directory
    train_list : List
        A list containing the name of the images.
    img_h : Int
        image height to be resized to.
    img_w : Int
        image width to be resized to.

    Returns
    -------
    img_labels : Nested List
        A nested list containing the loaded images along with their
        correcponding labels.
    """
    img_labels = []

    for item in enumerate(data_list):

        if os.path.isdir(os.path.join(data_path,item[1])):
            image_list = os.listdir(os.path.join(data_path,item[1]))
            for image in enumerate(image_list):
                img = imread(os.path.join(data_path, item[1], image[1]), as_gray=True)  # "as_grey"
                img = resize(img, (img_h, img_w), anti_aliasing=True).astype('float32')
                img_labels.append([np.array(img), gen_labels(item[1], class_list)])
                
                if image[0] % 100 == 0:
                    print('Reading: {0}/{1}  of train images'.format(image[0], len(image_list)))
        else:
            img = imread(os.path.join(data_path, item[1]), as_gray=True)  # "as_grey"
            img = resize(img, (img_h, img_w), anti_aliasing=True).astype('float32')
            img_labels.append([np.array(img), gen_labels(item[1], class_list)])

            if item[0] % 100 == 0:
                print('Reading: {0}/{1}  of train images'.format(item[0], len(data_list)))

    shuffle(img_labels)
    return img_labels


def get_data_arrays(nested_list, img_h, img_w):
    """
    Parameters
    ----------
    nested_list : nested list
        nested list of image arrays with corresponding class labels.
    img_h : Int
        Image height.
    img_w : Int
        Image width.

    Returns
    -------
    img_arrays : Numpy array
        4D Array with the size of (n_data,img_h,img_w, 1)
    label_arrays : Numpy array
        1D array with the size (n_data).

    """
    img_arrays = np.zeros((len(nested_list), img_h, img_w), dtype=np.float32)
    label_arrays = np.zeros((len(nested_list)), dtype=np.int32)
    for ind in range(len(nested_list)):
        img_arrays[ind] = nested_list[ind][0]
        label_arrays[ind] = nested_list[ind][1]
    img_arrays = np.expand_dims(img_arrays, axis=3)
    return img_arrays, label_arrays


def get_train_test_arrays(train_data_path, test_data_path, train_list,
                          test_list, img_h, img_w, class_list):
    """
    Get the directory to the train and test sets, the files names and
    the size of the image and return the image and label arrays for
    train and test sets.
    """

    train_data = get_data(train_data_path, train_list, img_h, img_w, class_list)
    test_data = get_data(test_data_path, test_list, img_h, img_w, class_list)

    train_img, train_label = get_data_arrays(train_data, img_h, img_w)
    test_img, test_label = get_data_arrays(test_data, img_h, img_w)
    del (train_data)
    del (test_data)
    return train_img, test_img, train_label, test_label

# %%
# Data and model parameters
img_ch, img_width, img_height = 1, 128, 128

data_path = '/DL_course_data/Lab2/Skin'  # Path to data root with two subdirs.

class_list = ['Mel','Nevi']

train_data_path = os.path.join(data_path, 'train')
test_data_path = os.path.join(data_path, 'validation')


train_list = os.listdir(train_data_path)
test_list = os.listdir(test_data_path)

x_train, x_test, y_train, y_test = get_train_test_arrays(
    train_data_path, test_data_path,
    train_list, test_list, img_height, img_width, class_list)
# Out:
# Reading: 0/500  of train images
# Reading: 100/500  of train images
# Reading: 200/500  of train images
# Reading: 300/500  of train images
# Reading: 400/500  of train images
# Reading: 0/500  of train images
# Reading: 100/500  of train images
# Reading: 200/500  of train images
# Reading: 300/500  of train images
# Reading: 400/500  of train images
# Reading: 0/100  of train images
# Reading: 0/100  of train images

# %%
n_epochs = 50
batch_s = 8
n_base = 8
learn_r = 0.0001

# %%
def model(img_ch, img_width, img_height, n_base):
    
    model = Sequential()
    
    model.add(Conv2D(filters=n_base, input_shape=(img_width, img_height, img_ch),
                     kernel_size=(3,3), strides=(1,1), padding='same'))
#     model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=n_base*2, kernel_size=(3,3), strides=(1,1), padding='same'))
#     model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=n_base*4, kernel_size=(3,3), strides=(1,1), padding='same'))
#     model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Conv2D(filters=n_base*4, kernel_size=(3,3), strides=(1,1), padding='same'))
#     model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Conv2D(filters=n_base*2, kernel_size=(3,3), strides=(1,1), padding='same'))
#     model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dense(64))
    model.add(Activation('relu'))
#     model.add(Dropout(0.4))

    model.add(Dense(64))
    model.add(Activation('relu'))
#     model.add(Dropout(0.4))

    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.summary()   
    return model

# %%
MLP = model(img_ch, img_width, img_height, n_base)         # Model Instantiating
MLP.compile(loss = 'binary_crossentropy',          # Model Compiling   
              optimizer = Adam(lr = learn_r),
              metrics = ['binary_accuracy'])

History = MLP.fit(x_train, y_train, batch_size = batch_s,
                  validation_data = (x_test, y_test),
                  epochs = n_epochs, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 8)       80
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 64, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 16)        4624
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                262208
# _________________________________________________________________
# activation_5 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# activation_6 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_7 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 286,193
# Trainable params: 286,193
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1000 samples, validate on 200 samples
# Epoch 1/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.6941 - binary_accuracy: 0.4810 - val_loss: 0.6921 - val_binary_accuracy: 0.5000
# Epoch 2/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.6910 - binary_accuracy: 0.5140 - val_loss: 0.6905 - val_binary_accuracy: 0.5500
# Epoch 3/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.6873 - binary_accuracy: 0.5790 - val_loss: 0.6803 - val_binary_accuracy: 0.5000
# Epoch 4/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.6545 - binary_accuracy: 0.6620 - val_loss: 0.6054 - val_binary_accuracy: 0.7250
# Epoch 5/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5834 - binary_accuracy: 0.7210 - val_loss: 0.5434 - val_binary_accuracy: 0.7400
# Epoch 6/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5704 - binary_accuracy: 0.7300 - val_loss: 0.5642 - val_binary_accuracy: 0.7700
# Epoch 7/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5553 - binary_accuracy: 0.7380 - val_loss: 0.5206 - val_binary_accuracy: 0.7900
# Epoch 8/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5280 - binary_accuracy: 0.7590 - val_loss: 0.5026 - val_binary_accuracy: 0.8000
# Epoch 9/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5258 - binary_accuracy: 0.7570 - val_loss: 0.5714 - val_binary_accuracy: 0.7900
# Epoch 10/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5296 - binary_accuracy: 0.7450 - val_loss: 0.5060 - val_binary_accuracy: 0.8050
# Epoch 11/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5245 - binary_accuracy: 0.7490 - val_loss: 0.5380 - val_binary_accuracy: 0.7600
# Epoch 12/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5095 - binary_accuracy: 0.7650 - val_loss: 0.5111 - val_binary_accuracy: 0.7950
# Epoch 13/50
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5173 - binary_accuracy: 0.7660 - val_loss: 0.5011 - val_binary_accuracy: 0.8000
# Epoch 14/50
#  400/1000 [===========>..................] - ETA: 2s - loss: 0.5379 - binary_accuracy: 0.7400

# %%
plt.figure(figsize=(4, 4))
plt.title("Learning curve")
plt.plot(History.history["loss"], label="loss")
plt.plot(History.history["val_loss"], label="val_loss")
plt.plot( np.argmin(History.history["val_loss"]),
         np.min(History.history["val_loss"]),
         marker="x", color="r", label="best model")

plt.xlabel("Epochs")
plt.ylabel("Loss Value")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(4, 4))
plt.title("Accuracy")
plt.plot(History.history["binary_accuracy"], label="accuracy")
plt.plot(History.history["val_binary_accuracy"], label="val_accuracy")
plt.plot( np.argmax(History.history["val_binary_accuracy"]),
         np.max(History.history["val_binary_accuracy"]),
         marker="x", color="r", label="best model")

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # Task 2

# %%
def model(img_ch, img_width, img_height, n_base):
    
    model = Sequential()
    
    model.add(Conv2D(filters=n_base, input_shape=(img_width, img_height, img_ch),
                     kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))
    model.add(SpatialDropout2D(0.1))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=n_base*2, kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))
    model.add(SpatialDropout2D(0.1))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=n_base*4, kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))
    model.add(SpatialDropout2D(0.1))

    model.add(Conv2D(filters=n_base*4, kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))
    model.add(SpatialDropout2D(0.1))

    model.add(Conv2D(filters=n_base*2, kernel_size=(3,3), strides=(1,1), padding='same'))
    model.add(Activation('relu'))
    model.add(SpatialDropout2D(0.1))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.summary()   
    return model

# %%
n_epochs = 150
batch_s = 8
n_base = 32
learn_r = 0.00001
MLP = model(img_ch, img_width, img_height, n_base)         # Model Instantiating
MLP.compile(loss = 'binary_crossentropy',          # Model Compiling   
              optimizer = Adam(lr = learn_r),
              metrics = ['binary_accuracy'])

History = MLP.fit(x_train, y_train, batch_size = batch_s,
                  validation_data = (x_test, y_test),
                  epochs = n_epochs, verbose=1)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 128, 128, 32)      320
#
#  activation_17 (Activation)  (None, 128, 128, 32)      0
#
#  spatial_dropout2d (SpatialD  (None, 128, 128, 32)     0
#  ropout2D)
#
#  max_pooling2d_6 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 64)        18496
#
#  activation_18 (Activation)  (None, 64, 64, 64)        0
#
#  spatial_dropout2d_1 (Spatia  (None, 64, 64, 64)       0
#  lDropout2D)
#
#  max_pooling2d_7 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 128)       73856
#
#  activation_19 (Activation)  (None, 32, 32, 128)       0
#
#  spatial_dropout2d_2 (Spatia  (None, 32, 32, 128)      0
#  lDropout2D)
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 128)       147584
#
#  activation_20 (Activation)  (None, 32, 32, 128)       0
#
#  spatial_dropout2d_3 (Spatia  (None, 32, 32, 128)      0
#  lDropout2D)
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 64)        73792
#
#  activation_21 (Activation)  (None, 32, 32, 64)        0
#
#  spatial_dropout2d_4 (Spatia  (None, 32, 32, 64)       0
#  lDropout2D)
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 16384)             0
#
#  dense_6 (Dense)             (None, 64)                1048640
#
#  activation_22 (Activation)  (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  activation_23 (Activation)  (None, 64)                0
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 1)                 65
#
#  activation_24 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 1,366,913
# Trainable params: 1,366,913
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 125/125 [==============================] - 1s 4ms/step - loss: 0.6923 - binary_accuracy: 0.5200 - val_loss: 0.6928 - val_binary_accuracy: 0.5000
# Epoch 2/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6922 - binary_accuracy: 0.5250 - val_loss: 0.6927 - val_binary_accuracy: 0.5000
# Epoch 3/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6938 - binary_accuracy: 0.5050 - val_loss: 0.6929 - val_binary_accuracy: 0.5000
# Epoch 4/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6948 - binary_accuracy: 0.4730 - val_loss: 0.6927 - val_binary_accuracy: 0.5000
# Epoch 5/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6922 - binary_accuracy: 0.5150 - val_loss: 0.6927 - val_binary_accuracy: 0.5050
# Epoch 6/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6924 - binary_accuracy: 0.5110 - val_loss: 0.6924 - val_binary_accuracy: 0.5300
# Epoch 7/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6917 - binary_accuracy: 0.5170 - val_loss: 0.6923 - val_binary_accuracy: 0.5000
# Epoch 8/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6924 - binary_accuracy: 0.5010 - val_loss: 0.6920 - val_binary_accuracy: 0.5000
# Epoch 9/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6929 - binary_accuracy: 0.4950 - val_loss: 0.6921 - val_binary_accuracy: 0.5150
# Epoch 10/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6939 - binary_accuracy: 0.5100 - val_loss: 0.6918 - val_binary_accuracy: 0.7100
# Epoch 11/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6924 - binary_accuracy: 0.5010 - val_loss: 0.6915 - val_binary_accuracy: 0.5600
# Epoch 12/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6932 - binary_accuracy: 0.5040 - val_loss: 0.6917 - val_binary_accuracy: 0.6400
# Epoch 13/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6935 - binary_accuracy: 0.4880 - val_loss: 0.6914 - val_binary_accuracy: 0.6400
# Epoch 14/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6933 - binary_accuracy: 0.5110 - val_loss: 0.6913 - val_binary_accuracy: 0.5800
# Epoch 15/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6917 - binary_accuracy: 0.5280 - val_loss: 0.6911 - val_binary_accuracy: 0.5850
# Epoch 16/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6913 - binary_accuracy: 0.5370 - val_loss: 0.6913 - val_binary_accuracy: 0.5450
# Epoch 17/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6917 - binary_accuracy: 0.5370 - val_loss: 0.6911 - val_binary_accuracy: 0.5100
# Epoch 18/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6913 - binary_accuracy: 0.5400 - val_loss: 0.6907 - val_binary_accuracy: 0.5100
# Epoch 19/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6911 - binary_accuracy: 0.5320 - val_loss: 0.6901 - val_binary_accuracy: 0.5300
# Epoch 20/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6893 - binary_accuracy: 0.5370 - val_loss: 0.6895 - val_binary_accuracy: 0.5350
# Epoch 21/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6929 - binary_accuracy: 0.5060 - val_loss: 0.6895 - val_binary_accuracy: 0.5950
# Epoch 22/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6923 - binary_accuracy: 0.5120 - val_loss: 0.6892 - val_binary_accuracy: 0.6550
# Epoch 23/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6916 - binary_accuracy: 0.5250 - val_loss: 0.6881 - val_binary_accuracy: 0.7000
# Epoch 24/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6910 - binary_accuracy: 0.5320 - val_loss: 0.6877 - val_binary_accuracy: 0.5200
# Epoch 25/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6884 - binary_accuracy: 0.5340 - val_loss: 0.6861 - val_binary_accuracy: 0.5700
# Epoch 26/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6917 - binary_accuracy: 0.5320 - val_loss: 0.6864 - val_binary_accuracy: 0.5900
# Epoch 27/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6869 - binary_accuracy: 0.5490 - val_loss: 0.6846 - val_binary_accuracy: 0.5400
# Epoch 28/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6891 - binary_accuracy: 0.5320 - val_loss: 0.6852 - val_binary_accuracy: 0.6800
# Epoch 29/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6905 - binary_accuracy: 0.5270 - val_loss: 0.6833 - val_binary_accuracy: 0.6450
# Epoch 30/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6855 - binary_accuracy: 0.5650 - val_loss: 0.6818 - val_binary_accuracy: 0.6250
# Epoch 31/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6889 - binary_accuracy: 0.5360 - val_loss: 0.6851 - val_binary_accuracy: 0.6700
# Epoch 32/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6860 - binary_accuracy: 0.5710 - val_loss: 0.6829 - val_binary_accuracy: 0.6350
# Epoch 33/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6883 - binary_accuracy: 0.5450 - val_loss: 0.6812 - val_binary_accuracy: 0.6700
# Epoch 34/150
# 125/125 [==============================] - 0s 4ms/step - loss: 0.6879 - binary_accuracy: 0.5520 - val_loss: 0.6828 - val_binary_accuracy: 0.5800
# Epoch 35/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6811 - binary_accuracy: 0.5760 - val_loss: 0.6764 - val_binary_accuracy: 0.6800
# Epoch 36/150
# 125/125 [==============================] - 0s 4ms/step - loss: 0.6806 - binary_accuracy: 0.5660 - val_loss: 0.6731 - val_binary_accuracy: 0.6350
# Epoch 37/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6855 - binary_accuracy: 0.5600 - val_loss: 0.6749 - val_binary_accuracy: 0.6650
# Epoch 38/150
# 125/125 [==============================] - 0s 4ms/step - loss: 0.6866 - binary_accuracy: 0.5520 - val_loss: 0.6714 - val_binary_accuracy: 0.6100
# Epoch 39/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6782 - binary_accuracy: 0.5830 - val_loss: 0.6688 - val_binary_accuracy: 0.6700
# Epoch 40/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6796 - binary_accuracy: 0.5690 - val_loss: 0.6820 - val_binary_accuracy: 0.5350
# Epoch 41/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6809 - binary_accuracy: 0.5840 - val_loss: 0.6651 - val_binary_accuracy: 0.7050
# Epoch 42/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6770 - binary_accuracy: 0.5770 - val_loss: 0.6672 - val_binary_accuracy: 0.6700
# Epoch 43/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6757 - binary_accuracy: 0.6080 - val_loss: 0.6615 - val_binary_accuracy: 0.7150
# Epoch 44/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6728 - binary_accuracy: 0.5820 - val_loss: 0.6666 - val_binary_accuracy: 0.6400
# Epoch 45/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6735 - binary_accuracy: 0.5860 - val_loss: 0.6702 - val_binary_accuracy: 0.5750
# Epoch 46/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6679 - binary_accuracy: 0.5980 - val_loss: 0.6562 - val_binary_accuracy: 0.6700
# Epoch 47/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6697 - binary_accuracy: 0.5920 - val_loss: 0.6491 - val_binary_accuracy: 0.6750
# Epoch 48/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6691 - binary_accuracy: 0.5940 - val_loss: 0.6482 - val_binary_accuracy: 0.6600
# Epoch 49/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6699 - binary_accuracy: 0.6120 - val_loss: 0.6478 - val_binary_accuracy: 0.6850
# Epoch 50/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6666 - binary_accuracy: 0.5970 - val_loss: 0.6447 - val_binary_accuracy: 0.6900
# Epoch 51/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6650 - binary_accuracy: 0.6200 - val_loss: 0.6408 - val_binary_accuracy: 0.7200
# Epoch 52/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6621 - binary_accuracy: 0.6140 - val_loss: 0.6417 - val_binary_accuracy: 0.7050
# Epoch 53/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6547 - binary_accuracy: 0.6280 - val_loss: 0.6443 - val_binary_accuracy: 0.6800
# Epoch 54/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6621 - binary_accuracy: 0.6100 - val_loss: 0.6512 - val_binary_accuracy: 0.6650
# Epoch 55/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6550 - binary_accuracy: 0.6410 - val_loss: 0.6299 - val_binary_accuracy: 0.7150
# Epoch 56/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6562 - binary_accuracy: 0.6220 - val_loss: 0.6297 - val_binary_accuracy: 0.7150
# Epoch 57/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6558 - binary_accuracy: 0.6370 - val_loss: 0.6262 - val_binary_accuracy: 0.7150
# Epoch 58/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6573 - binary_accuracy: 0.6120 - val_loss: 0.6334 - val_binary_accuracy: 0.6850
# Epoch 59/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6551 - binary_accuracy: 0.6290 - val_loss: 0.6299 - val_binary_accuracy: 0.7100
# Epoch 60/150
# 125/125 [==============================] - 0s 4ms/step - loss: 0.6438 - binary_accuracy: 0.6390 - val_loss: 0.6173 - val_binary_accuracy: 0.7150
# Epoch 61/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6519 - binary_accuracy: 0.6070 - val_loss: 0.6285 - val_binary_accuracy: 0.6950
# Epoch 62/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6398 - binary_accuracy: 0.6540 - val_loss: 0.6271 - val_binary_accuracy: 0.6800
# Epoch 63/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6426 - binary_accuracy: 0.6400 - val_loss: 0.6095 - val_binary_accuracy: 0.7450
# Epoch 64/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6451 - binary_accuracy: 0.6340 - val_loss: 0.6058 - val_binary_accuracy: 0.7500
# Epoch 65/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6410 - binary_accuracy: 0.6490 - val_loss: 0.6069 - val_binary_accuracy: 0.7200
# Epoch 66/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6408 - binary_accuracy: 0.6500 - val_loss: 0.6236 - val_binary_accuracy: 0.6850
# Epoch 67/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6345 - binary_accuracy: 0.6590 - val_loss: 0.6207 - val_binary_accuracy: 0.6900
# Epoch 68/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6380 - binary_accuracy: 0.6600 - val_loss: 0.6117 - val_binary_accuracy: 0.7100
# Epoch 69/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6290 - binary_accuracy: 0.6550 - val_loss: 0.6103 - val_binary_accuracy: 0.7100
# Epoch 70/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6264 - binary_accuracy: 0.6890 - val_loss: 0.5934 - val_binary_accuracy: 0.7650
# Epoch 71/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6206 - binary_accuracy: 0.6730 - val_loss: 0.6024 - val_binary_accuracy: 0.7150
# Epoch 72/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6235 - binary_accuracy: 0.6730 - val_loss: 0.6037 - val_binary_accuracy: 0.7150
# Epoch 73/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6304 - binary_accuracy: 0.6760 - val_loss: 0.5988 - val_binary_accuracy: 0.7250
# Epoch 74/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6133 - binary_accuracy: 0.6910 - val_loss: 0.5870 - val_binary_accuracy: 0.7350
# Epoch 75/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6182 - binary_accuracy: 0.6880 - val_loss: 0.5868 - val_binary_accuracy: 0.7450
# Epoch 76/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6160 - binary_accuracy: 0.6700 - val_loss: 0.5809 - val_binary_accuracy: 0.7550
# Epoch 77/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6016 - binary_accuracy: 0.7010 - val_loss: 0.5769 - val_binary_accuracy: 0.7700
# Epoch 78/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6192 - binary_accuracy: 0.6760 - val_loss: 0.5848 - val_binary_accuracy: 0.7550
# Epoch 79/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6051 - binary_accuracy: 0.6940 - val_loss: 0.5696 - val_binary_accuracy: 0.7600
# Epoch 80/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6134 - binary_accuracy: 0.6960 - val_loss: 0.5809 - val_binary_accuracy: 0.7500
# Epoch 81/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5909 - binary_accuracy: 0.7220 - val_loss: 0.5711 - val_binary_accuracy: 0.7600
# Epoch 82/150
# 125/125 [==============================] - 0s 4ms/step - loss: 0.5942 - binary_accuracy: 0.6950 - val_loss: 0.5595 - val_binary_accuracy: 0.7750
# Epoch 83/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6048 - binary_accuracy: 0.6980 - val_loss: 0.5662 - val_binary_accuracy: 0.7650
# Epoch 84/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5941 - binary_accuracy: 0.6950 - val_loss: 0.5590 - val_binary_accuracy: 0.7750
# Epoch 85/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5909 - binary_accuracy: 0.7030 - val_loss: 0.5533 - val_binary_accuracy: 0.7750
# Epoch 86/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5802 - binary_accuracy: 0.7070 - val_loss: 0.5735 - val_binary_accuracy: 0.7200
# Epoch 87/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5830 - binary_accuracy: 0.7280 - val_loss: 0.5635 - val_binary_accuracy: 0.7350
# Epoch 88/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5948 - binary_accuracy: 0.7180 - val_loss: 0.5773 - val_binary_accuracy: 0.7050
# Epoch 89/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5783 - binary_accuracy: 0.7270 - val_loss: 0.5495 - val_binary_accuracy: 0.7700
# Epoch 90/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5781 - binary_accuracy: 0.7190 - val_loss: 0.5429 - val_binary_accuracy: 0.7750
# Epoch 91/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5813 - binary_accuracy: 0.7330 - val_loss: 0.5557 - val_binary_accuracy: 0.7450
# Epoch 92/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5782 - binary_accuracy: 0.7280 - val_loss: 0.5583 - val_binary_accuracy: 0.7550
# Epoch 93/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5898 - binary_accuracy: 0.7030 - val_loss: 0.5827 - val_binary_accuracy: 0.6900
# Epoch 94/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5762 - binary_accuracy: 0.7280 - val_loss: 0.5578 - val_binary_accuracy: 0.7050
# Epoch 95/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5684 - binary_accuracy: 0.7260 - val_loss: 0.5431 - val_binary_accuracy: 0.7700
# Epoch 96/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5808 - binary_accuracy: 0.7140 - val_loss: 0.5417 - val_binary_accuracy: 0.7700
# Epoch 97/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5621 - binary_accuracy: 0.7210 - val_loss: 0.5344 - val_binary_accuracy: 0.7700
# Epoch 98/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5617 - binary_accuracy: 0.7460 - val_loss: 0.5381 - val_binary_accuracy: 0.7700
# Epoch 99/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5659 - binary_accuracy: 0.7210 - val_loss: 0.5328 - val_binary_accuracy: 0.7750
# Epoch 100/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5452 - binary_accuracy: 0.7310 - val_loss: 0.5323 - val_binary_accuracy: 0.7650
# Epoch 101/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5702 - binary_accuracy: 0.7360 - val_loss: 0.5339 - val_binary_accuracy: 0.7650
# Epoch 102/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5565 - binary_accuracy: 0.7300 - val_loss: 0.5351 - val_binary_accuracy: 0.7550
# Epoch 103/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5750 - binary_accuracy: 0.7300 - val_loss: 0.5397 - val_binary_accuracy: 0.7500
# Epoch 104/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5587 - binary_accuracy: 0.7480 - val_loss: 0.5351 - val_binary_accuracy: 0.7650
# Epoch 105/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5592 - binary_accuracy: 0.7490 - val_loss: 0.5377 - val_binary_accuracy: 0.7650
# Epoch 106/150
# 125/125 [==============================] - 0s 4ms/step - loss: 0.5538 - binary_accuracy: 0.7440 - val_loss: 0.5355 - val_binary_accuracy: 0.7450
# Epoch 107/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5497 - binary_accuracy: 0.7270 - val_loss: 0.5226 - val_binary_accuracy: 0.7750
# Epoch 108/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5711 - binary_accuracy: 0.7500 - val_loss: 0.5316 - val_binary_accuracy: 0.7650
# Epoch 109/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5543 - binary_accuracy: 0.7450 - val_loss: 0.5249 - val_binary_accuracy: 0.7700
# Epoch 110/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5554 - binary_accuracy: 0.7510 - val_loss: 0.5238 - val_binary_accuracy: 0.7650
# Epoch 111/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5463 - binary_accuracy: 0.7500 - val_loss: 0.5235 - val_binary_accuracy: 0.7800
# Epoch 112/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5578 - binary_accuracy: 0.7350 - val_loss: 0.5329 - val_binary_accuracy: 0.7500
# Epoch 113/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5533 - binary_accuracy: 0.7490 - val_loss: 0.5190 - val_binary_accuracy: 0.7800
# Epoch 114/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5523 - binary_accuracy: 0.7480 - val_loss: 0.5177 - val_binary_accuracy: 0.7750
# Epoch 115/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5448 - binary_accuracy: 0.7530 - val_loss: 0.5391 - val_binary_accuracy: 0.7300
# Epoch 116/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5518 - binary_accuracy: 0.7640 - val_loss: 0.5296 - val_binary_accuracy: 0.7550
# Epoch 117/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5605 - binary_accuracy: 0.7460 - val_loss: 0.5203 - val_binary_accuracy: 0.7700
# Epoch 118/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5454 - binary_accuracy: 0.7490 - val_loss: 0.5188 - val_binary_accuracy: 0.7750
# Epoch 119/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5561 - binary_accuracy: 0.7280 - val_loss: 0.5167 - val_binary_accuracy: 0.7700
# Epoch 120/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5357 - binary_accuracy: 0.7580 - val_loss: 0.5057 - val_binary_accuracy: 0.7750
# Epoch 121/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5422 - binary_accuracy: 0.7680 - val_loss: 0.5112 - val_binary_accuracy: 0.7750
# Epoch 122/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5284 - binary_accuracy: 0.7600 - val_loss: 0.5133 - val_binary_accuracy: 0.7650
# Epoch 123/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5227 - binary_accuracy: 0.7640 - val_loss: 0.5209 - val_binary_accuracy: 0.7450
# Epoch 124/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5369 - binary_accuracy: 0.7610 - val_loss: 0.5206 - val_binary_accuracy: 0.7550
# Epoch 125/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5419 - binary_accuracy: 0.7610 - val_loss: 0.5048 - val_binary_accuracy: 0.7800
# Epoch 126/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5231 - binary_accuracy: 0.7770 - val_loss: 0.5147 - val_binary_accuracy: 0.7600
# Epoch 127/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5320 - binary_accuracy: 0.7610 - val_loss: 0.5067 - val_binary_accuracy: 0.7800
# Epoch 128/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5456 - binary_accuracy: 0.7480 - val_loss: 0.5101 - val_binary_accuracy: 0.7850
# Epoch 129/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5377 - binary_accuracy: 0.7450 - val_loss: 0.5132 - val_binary_accuracy: 0.7700
# Epoch 130/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5368 - binary_accuracy: 0.7460 - val_loss: 0.5061 - val_binary_accuracy: 0.7850
# Epoch 131/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5266 - binary_accuracy: 0.7700 - val_loss: 0.4994 - val_binary_accuracy: 0.7900
# Epoch 132/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5337 - binary_accuracy: 0.7540 - val_loss: 0.5054 - val_binary_accuracy: 0.7800
# Epoch 133/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5281 - binary_accuracy: 0.7720 - val_loss: 0.5014 - val_binary_accuracy: 0.7850
# Epoch 134/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5193 - binary_accuracy: 0.7680 - val_loss: 0.5032 - val_binary_accuracy: 0.7700
# Epoch 135/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5221 - binary_accuracy: 0.7570 - val_loss: 0.5014 - val_binary_accuracy: 0.7700
# Epoch 136/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5328 - binary_accuracy: 0.7560 - val_loss: 0.4972 - val_binary_accuracy: 0.7950
# Epoch 137/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5298 - binary_accuracy: 0.7680 - val_loss: 0.4984 - val_binary_accuracy: 0.7750
# Epoch 138/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5337 - binary_accuracy: 0.7690 - val_loss: 0.4998 - val_binary_accuracy: 0.7700
# Epoch 139/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5156 - binary_accuracy: 0.7600 - val_loss: 0.4927 - val_binary_accuracy: 0.7900
# Epoch 140/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5145 - binary_accuracy: 0.7580 - val_loss: 0.4926 - val_binary_accuracy: 0.7750
# Epoch 141/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5216 - binary_accuracy: 0.7540 - val_loss: 0.4946 - val_binary_accuracy: 0.7750
# Epoch 142/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5086 - binary_accuracy: 0.7810 - val_loss: 0.5182 - val_binary_accuracy: 0.7550
# Epoch 143/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5421 - binary_accuracy: 0.7520 - val_loss: 0.4927 - val_binary_accuracy: 0.7950
# Epoch 144/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5236 - binary_accuracy: 0.7630 - val_loss: 0.5083 - val_binary_accuracy: 0.7550
# Epoch 145/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5154 - binary_accuracy: 0.7630 - val_loss: 0.5016 - val_binary_accuracy: 0.7550
# Epoch 146/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5098 - binary_accuracy: 0.7720 - val_loss: 0.4878 - val_binary_accuracy: 0.7950
# Epoch 147/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5235 - binary_accuracy: 0.7630 - val_loss: 0.4861 - val_binary_accuracy: 0.7900
# Epoch 148/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5242 - binary_accuracy: 0.7540 - val_loss: 0.4938 - val_binary_accuracy: 0.7850
# Epoch 149/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5167 - binary_accuracy: 0.7580 - val_loss: 0.4965 - val_binary_accuracy: 0.7700
# Epoch 150/150
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5229 - binary_accuracy: 0.7710 - val_loss: 0.4887 - val_binary_accuracy: 0.7850
