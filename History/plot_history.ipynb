# %%
import matplotlib.pyplot as plt
import pandas as pd


df = pd.read_csv('/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_loss.csv')
df_ = pd.read_csv('/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_val_loss.csv')

# %%
df
# Out:
#        Wall time  Step     Value
# 0   1.668694e+09     0 -0.064131
# 1   1.668695e+09     1 -0.123377
# 2   1.668696e+09     2 -0.229111
# 3   1.668697e+09     3 -0.392901
# 4   1.668697e+09     4 -0.550321
# ..           ...   ...       ...
# 95  1.668771e+09    95 -0.854199
# 96  1.668772e+09    96 -0.854377
# 97  1.668773e+09    97 -0.854539
# 98  1.668774e+09    98 -0.854914
# 99  1.668774e+09    99 -0.855232
#
# [100 rows x 3 columns]

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
def plot_dice(csv_paths,modelname):
    df = pd.read_csv(csv_paths[2])
    df_ = pd.read_csv(csv_paths[3])
    res = pd.DataFrame()
    res['epoch'] = df['Step']
    res['dice'] = df['Value']
    res['val_dice'] = df_['Value']
    # res[['epoch', 'dice', 'val_dice']].plot(
    #     x='epoch',
    #     xlabel='Epochs',
    #     ylabel='dice_coef',
    #     title='')
    fig = plt.figure(figsize=(3, 3))
    plt.plot(res["dice"], label="dice_coef")
    plt.plot(res["val_dice"], label="val_dice_coef")
    plt.plot( np.argmax(res["val_dice"]),
            np.max(res["val_dice"]),
            marker="x", color="r", label="best model")
    plt.title("Dice coef")
    plt.xlabel("Epochs")
    plt.ylabel("dice_coef")
    plt.legend()
    plt.show()
    fig.savefig(modelname+"_dice")
    return fig

def plot_loss(csv_paths,modelname):
    df = pd.read_csv(csv_paths[0])
    df_ = pd.read_csv(csv_paths[1])
    res = pd.DataFrame()
    res['epoch'] = df['Step']
    res['loss'] = df['Value']
    res['val_loss'] = df_['Value']

    fig = plt.figure(figsize=(3, 3))
    plt.plot(res['loss'], label="loss")
    plt.plot(res['val_loss'], label="val_loss")
    plt.plot(np.argmin(res['val_loss']),
            np.min(res['val_loss']),
            marker="x", color="r", label="best model")
    plt.title("Learning curve")
    plt.xlabel("Epochs")
    plt.ylabel("loss")
    plt.legend()
    plt.show()
    fig.savefig(modelname+"_loss")
    return fig

def plot_precision(csv_paths,modelname):
    df = pd.read_csv(csv_paths[4])
    df_ = pd.read_csv(csv_paths[5])
    res = pd.DataFrame()
    res['epoch'] = df['Step']
    res['precision'] = df['Value']
    res['val_precision'] = df_['Value']

    fig = plt.figure(figsize=(3, 3))
    plt.plot(res['precision'], label="precision")
    plt.plot(res['val_precision'], label="val_precision")
    plt.plot(np.argmax(res['val_precision']),
            np.max(res['val_precision']),
            marker="x", color="r", label="best model")
    plt.title("Precision")
    plt.xlabel("Epochs")
    plt.ylabel("precision")
    plt.legend()
    plt.show()
    fig.savefig(modelname+"_precision")
    return fig

def plot_recall(csv_paths,modelname):
    df = pd.read_csv(csv_paths[6])
    df_ = pd.read_csv(csv_paths[7])
    res = pd.DataFrame()
    res['epoch'] = df['Step']
    res['recall'] = df['Value']
    res['val_recall'] = df_['Value']

    fig = plt.figure(figsize=(3, 3))
    plt.plot(res['recall'], label="recall")
    plt.plot(res['val_recall'], label="val_recall")
    plt.plot(np.argmax(res['val_recall']),
            np.max(res['val_recall']),
            marker="x", color="r", label="best model")
    plt.title("Recall")
    plt.xlabel("Epochs")
    plt.ylabel("recall")
    plt.legend()
    plt.show()
    fig.savefig(modelname+"_recall")
    return fig

# %%
a = plot_loss(loss_paths,pre_label_pre)
type(a)
# Out:
# NoneType

# %%
loss_paths = [
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_loss.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_val_loss.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_dice_coef.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_val_dice_coef.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_precision.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_val_precision.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_recall.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-pretrain1117-1457-tag-epoch_val_recall.csv']
pre_label_pre = "pretrain_model"
plot_loss(loss_paths,pre_label_pre)
plot_dice(loss_paths,pre_label_pre)
plot_precision(loss_paths,pre_label_pre)
plot_recall(loss_paths,pre_label_pre)

# %%
/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-cv_Unet_wmap_no_aug_e150_w_11122-1748-tag-epoch_dice_coef.csv

# %%
loss_paths = [
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-cv_Unet_wmap_no_aug_e150_w_11122-1748-tag-epoch_loss.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-cv_Unet_wmap_no_aug_e150_w_11122-1748-tag-epoch_val_loss.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-cv_Unet_wmap_no_aug_e150_w_11122-1748-tag-epoch_dice_coef.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-cv_Unet_wmap_no_aug_e150_w_11122-1748-tag-epoch_val_dice_coef.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-cv_Unet_wmap_no_aug_e150_w_11122-1748-tag-epoch_precision.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-cv_Unet_wmap_no_aug_e150_w_11122-1748-tag-epoch_val_precision.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-cv_Unet_wmap_no_aug_e150_w_11122-1748-tag-epoch_recall.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-cv_Unet_wmap_no_aug_e150_w_11122-1748-tag-epoch_val_recall.csv']
pre_label_pre = "lesion_model"
plot_loss(loss_paths,pre_label_pre)
plot_dice(loss_paths,pre_label_pre)
plot_precision(loss_paths,pre_label_pre)
plot_recall(loss_paths,pre_label_pre)

# %%
loss_paths = [
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_1_lr_5_1127-1145-tag-epoch_loss.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_1_lr_5_1127-1145-tag-epoch_val_loss.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_1_lr_5_1127-1145-tag-epoch_dice_coef.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_1_lr_5_1127-1145-tag-epoch_val_dice_coef.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_1_lr_5_1127-1145-tag-epoch_precision.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_1_lr_5_1127-1145-tag-epoch_val_precision.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_1_lr_5_1127-1145-tag-epoch_recall.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_1_lr_5_1127-1145-tag-epoch_val_recall.csv']
pre_label_pre = "transfer_learning_model"
plot_loss(loss_paths,pre_label_pre)
plot_dice(loss_paths,pre_label_pre)
plot_precision(loss_paths,pre_label_pre)
plot_recall(loss_paths,pre_label_pre)

# %%
res = pd.DataFrame()
res['epoch'] = df['Step']
res['dice'] = df['Value']
res['val_dice'] = df_['Value']
res
# Out:
#     epoch      dice  val_dice
# 0       0  0.072018  0.104056
# 1       1  0.138093  0.181095
# 2       2  0.255217  0.320036
# 3       3  0.434590  0.515193
# 4       4  0.604745  0.625190
# ..    ...       ...       ...
# 95     95  0.927244  0.917655
# 96     96  0.927483  0.919429
# 97     97  0.927742  0.927888
# 98     98  0.928113  0.923681
# 99     99  0.928284  0.923845
#
# [100 rows x 3 columns]

# %%
res[['epoch', 'dice', 'val_dice']].plot(
    x='epoch',
    xlabel='x',
    ylabel='y',
    title='Dice VS Val_Dice'
)

plt.show()

# %%
loss_paths = [
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_0_8_lr_5_1129-1409-tag-epoch_loss.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_0_8_lr_5_1129-1409-tag-epoch_val_loss.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_0_8_lr_5_1129-1409-tag-epoch_dice_coef.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_0_8_lr_5_1129-1409-tag-epoch_val_dice_coef.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_0_8_lr_5_1129-1409-tag-epoch_precision.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_0_8_lr_5_1129-1409-tag-epoch_val_precision.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_0_8_lr_5_1129-1409-tag-epoch_recall.csv',
        '/Users/xinyi/Documents/GitHub/deep_learning_G5/History/run-TL_Unet_wmap_n8_with_aug_e150_w_0_8_lr_5_1129-1409-tag-epoch_val_recall.csv']
pre_label_pre = "tf_model"
plot_loss(loss_paths,pre_label_pre)
plot_dice(loss_paths,pre_label_pre)
plot_precision(loss_paths,pre_label_pre)
plot_recall(loss_paths,pre_label_pre)
