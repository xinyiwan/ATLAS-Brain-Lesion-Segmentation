# %%
import numpy as np                  # for working with tensors outside the network
import pandas as pd                 # for data reading and writing
import matplotlib.pyplot as plt     # for data inspection
import os
from skimage.io import imread
from skimage.transform import resize

# %%
from keras.layers import Input, Conv2D, Activation, BatchNormalization, GlobalAveragePooling2D, Dense, Dropout
from keras.layers import add
from tensorflow.keras.layers import concatenate
from keras.activations import relu, softmax
from keras.models import Model
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, ModelCheckpoint

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
def block(n_output, upscale=False):
    # n_output: number of feature maps in the block
    # upscale: should we use the 1x1 conv2d mapping for shortcut or not
    
    # keras functional api: return the function of type
    # Tensor -> Tensor
    def f(x):
        
        # H_l(x):
        # first pre-activation
        h = BatchNormalization()(x)
        h = Activation(relu)(h)
        
        # first convolution
        h = Conv2D(kernel_size=3, filters=n_output, strides=1, padding='same', kernel_regularizer=regularizers.l2(0.01))(h)
        
        # second pre-activation
        h = BatchNormalization()(x)
        h = Activation(relu)(h)
        # second convolution
        h = Conv2D(kernel_size=3, filters=n_output, strides=1, padding='same', kernel_regularizer=regularizers.l2(0.01))(h)
        
        # f(x):
        if upscale:
            # 1x1 conv2d
            f = Conv2D(kernel_size=1, filters=n_output, strides=1, padding='same')(x)
        else:
            # identity
            f = x
        
        # F_l(x) = f(x) + H_l(x):
        return add([f, h])
    
    return f

# %%
# input tensor is the 128x128 grayscale image of X-ray
def ResNet():
    input_tensor = Input((128, 128, 1))

    # first conv2d with post-activation to transform the input data to some reasonable form
    x = Conv2D(kernel_size=3, filters=16, strides=1, padding='same', kernel_regularizer=regularizers.l2(0.01))(input_tensor)
    x = BatchNormalization()(x)
    x = Activation(relu)(x)

    # F_1
    x = block(16)(x)
    # F_2
    x = block(16)(x)

    # F_3
    # H_3 is the function from the tensor of size 28x28x16 to the the tensor of size 28x28x32
    # and we can't add together tensors of inconsistent sizes, so we use upscale=True
    # x = block(32, upscale=True)(x)       # !!! <------- Uncomment for local evaluation
    # F_4
    # x = block(32)(x)                     # !!! <------- Uncomment for local evaluation
    # F_5
    # x = block(32)(x)                     # !!! <------- Uncomment for local evaluation

    # F_6
    # x = block(48, upscale=True)(x)       # !!! <------- Uncomment for local evaluation
    # F_7
    # x = block(48)(x)                     # !!! <------- Uncomment for local evaluation

    # last activation of the entire network's output
    x = BatchNormalization()(x)
    x = Activation(relu)(x)

    # average pooling across the channels
    # 28x28x48 -> 1x48
    x = GlobalAveragePooling2D()(x)

    # dropout for more robust learning
    x = Dropout(0.2)(x)

    # last softmax layer
    x = Dense(units=9, kernel_regularizer=regularizers.l2(0.01))(x)
    x = Activation(softmax)(x)

    model = Model(inputs=input_tensor, outputs=x)
    return model

model = ResNet()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Data and model parameters
img_ch, img_width, img_height = 1, 128, 128
n_epochs = 80
Batch_Size = 32
Base = 8
LR = 0.00001

TRAIN_DIR = '/DL_course_data/Lab1/X_ray/train/'
VAL_DIR = '/DL_course_data/Lab1/X_ray/test/'

# %%
from random import shuffle

def gen_labels(im_name, pat1, pat2, pat3, pat4, pat5, pat6, pat7, pat8, pat9):
    '''
    Parameters
    ----------
    im_name : Str
        The image file name.
    pat1 : Str
        A string pattern in the filename for 1st class, e.g "Mel"
    pat2 : Str
        A string pattern in the filename 2nd class, e.g, "Nev"
    Returns
    -------
    Label : Numpy array
        Class label of the filename name based on its pattern.
    '''
    if pat1 in im_name:
        label = np.array([0])
    elif pat2 in im_name:
        label = np.array([1])
    elif pat3 in im_name:
        label = np.array([2])
    elif pat4 in im_name:
        label = np.array([3])
    elif pat5 in im_name:
        label = np.array([4])
    elif pat6 in im_name:
        label = np.array([5])
    elif pat7 in im_name:
        label = np.array([6])
    elif pat8 in im_name:
        label = np.array([7])
    elif pat9 in im_name:
        label = np.array([8])
    return label

def get_data(data_path, data_list, img_h, img_w):
    """
    Parameters
    ----------
    train_data_path : Str
        Path to the data directory
    train_list : List
        A list containing the name of the images.
    img_h : Int
        image height to be resized to.
    img_w : Int
        image width to be resized to.
    Returns
    -------
    img_labels : Nested List
        A nested list containing the loaded images along with their
        correcponding labels.
    """
    img_labels = []
    for item in enumerate(data_list):
        img = imread(os.path.join(data_path, item[1]), as_gray = True) # "as_grey"
        img = resize(img, (img_h, img_w), anti_aliasing = True).astype('float32')
        img_labels.append([np.array(img), gen_labels(item[1], 'C1', 'C2','C3','C4','C5','C6','C7','C8','C9')])
        if item[0] % 100 == 0:
             print('Reading: {0}/{1}  of train images'.format(item[0], len(data_list)))
    shuffle(img_labels)
    return img_labels

def get_data_arrays(nested_list, img_h, img_w):
    """
    Parameters
    ----------
    nested_list : nested list
        nested list of image arrays with corresponding class labels.
    img_h : Int
        Image height.
    img_w : Int
    Image width.
    Returns
    -------
    img_arrays : Numpy array
        4D Array with the size of (n_data,img_h,img_w, 1)
    label_arrays : Numpy array
        1D array with the size (n_data).
    """
    img_arrays = np.zeros((len(nested_list), img_h, img_w), dtype = np.float32)
    label_arrays = np.zeros((len(nested_list)), dtype = np.int32)
    for ind in range(len(nested_list)):
        img_arrays[ind] = nested_list[ind][0]
        label_arrays[ind] = nested_list[ind][1]
    img_arrays = np.expand_dims(img_arrays, axis =3)
    return img_arrays, label_arrays

def get_train_test_arrays(train_data_path, test_data_path, train_list,
                          test_list, img_h, img_w):
    """
    Get the directory to the train and test sets, the files names and
    the size of the image and return the image and label arrays for
    train and test sets.
    """
    train_data = get_data(train_data_path, train_list, img_h, img_w)
    test_data = get_data(test_data_path, test_list, img_h, img_w)
    train_img, train_label =  get_data_arrays(train_data, img_h, img_w)
    test_img, test_label = get_data_arrays(test_data, img_h, img_w)
    del(train_data)
    del(test_data)
    return train_img, test_img, train_label, test_label


img_w, img_h = 128, 128      # Setting the width and heights of the images.
data_path = '/DL_course_data/Lab1/X_ray'     # Path to data root with two subdirs.
train_data_path = os.path.join(data_path, 'train')
test_data_path = os.path.join(data_path, 'test')
train_list = os.listdir(train_data_path)
test_list = os.listdir(test_data_path)
x_train, x_test, y_train, y_test = get_train_test_arrays(
        train_data_path, test_data_path,
        train_list, test_list, img_h, img_w)
# Out:
# Reading: 0/5780  of train images
# Reading: 100/5780  of train images
# Reading: 200/5780  of train images
# Reading: 300/5780  of train images
# Reading: 400/5780  of train images
# Reading: 500/5780  of train images
# Reading: 600/5780  of train images
# Reading: 700/5780  of train images
# Reading: 800/5780  of train images
# Reading: 900/5780  of train images
# Reading: 1000/5780  of train images
# Reading: 1100/5780  of train images
# Reading: 1200/5780  of train images
# Reading: 1300/5780  of train images
# Reading: 1400/5780  of train images
# Reading: 1500/5780  of train images
# Reading: 1600/5780  of train images
# Reading: 1700/5780  of train images
# Reading: 1800/5780  of train images
# Reading: 1900/5780  of train images
# Reading: 2000/5780  of train images
# Reading: 2100/5780  of train images
# Reading: 2200/5780  of train images
# Reading: 2300/5780  of train images
# Reading: 2400/5780  of train images
# Reading: 2500/5780  of train images
# Reading: 2600/5780  of train images
# Reading: 2700/5780  of train images
# Reading: 2800/5780  of train images
# Reading: 2900/5780  of train images
# Reading: 3000/5780  of train images
# Reading: 3100/5780  of train images
# Reading: 3200/5780  of train images
# Reading: 3300/5780  of train images
# Reading: 3400/5780  of train images
# Reading: 3500/5780  of train images
# Reading: 3600/5780  of train images
# Reading: 3700/5780  of train images
# Reading: 3800/5780  of train images
# Reading: 3900/5780  of train images
# Reading: 4000/5780  of train images
# Reading: 4100/5780  of train images
# Reading: 4200/5780  of train images
# Reading: 4300/5780  of train images
# Reading: 4400/5780  of train images
# Reading: 4500/5780  of train images
# Reading: 4600/5780  of train images
# Reading: 4700/5780  of train images
# Reading: 4800/5780  of train images
# Reading: 4900/5780  of train images
# Reading: 5000/5780  of train images
# Reading: 5100/5780  of train images
# Reading: 5200/5780  of train images
# Reading: 5300/5780  of train images
# Reading: 5400/5780  of train images
# Reading: 5500/5780  of train images
# Reading: 5600/5780  of train images
# Reading: 5700/5780  of train images
# Reading: 0/450  of train images
# Reading: 100/450  of train images
# Reading: 200/450  of train images
# Reading: 300/450  of train images
# Reading: 400/450  of train images

# %%
import tensorflow as tf
y_train_n = tf.keras.utils.to_categorical(y_train,num_classes=9, dtype='float32')
y_test_n = tf.keras.utils.to_categorical(y_test,num_classes=9, dtype='float32')
len(x_train)
# Out:
# 5780

# %%
x = np.concatenate((x_train,x_test))
y = np.concatenate((y_train_n,y_test_n))

# %%
train_datagen = ImageDataGenerator(rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   rescale=1./255,
                                   horizontal_flip=True)
                    
x_train_generator = train_datagen.flow(x_train,  
                                    batch_size = Batch_Size)


# Create validation generator
val_datagen = ImageDataGenerator(rescale=1./255)
x_val_generator = val_datagen.flow(x_test, 
                                batch_size = Batch_Size,
                                seed=42)

# %%
# Define class weight for the inbalance in the dataset
from sklearn.utils import class_weight
def get_length(idx):
    return len(y_train[np.where(y_train == idx)])

labels_dict = {0: get_length(0), 1: get_length(1), 2: get_length(2), 3: get_length(3), 
                4: get_length(4), 5: get_length(5), 6: get_length(6), 7: get_length(7), 8: get_length(8)}

# %%
import math

def get_class_weight(labels_dict):
    """Calculate the weights of different categories"""
    total = sum(labels_dict.values())
    max_num = max(labels_dict.values())
    mu = 1.0 / (total / max_num)
    class_weight = dict()
    for key, value in labels_dict.items():
        score = math.log(mu * total / float(value))
        class_weight[key] = score if score > 1.0 else 1.0
    return class_weight

class_weight = get_class_weight(labels_dict)
class_weight
# Out:
# {0: 1.0,
#  1: 1.0,
#  2: 1.0,
#  3: 1.8360104809901925,
#  4: 2.1044875736059234,
#  5: 2.3043534400507877,
#  6: 2.3730303058470072,
#  7: 2.4018784601846654,
#  8: 2.467393067295292}

# %%
# Create checkpoint for the model, save the best model
mc = ModelCheckpoint('weights.best.keras', monitor='val_acc', save_best_only=True)

# %%
# Define learning rate scheduler 
# Use sigmoidal decay as the learning rate policy
def sigmoidal_decay(e, start=0, end=100, lr_start=1e-3, lr_end=1e-5):
    if e < start:
        return lr_start
    
    if e > end:
        return lr_end
    
    middle = (start + end) / 2
    s = lambda x: 1 / (1 + np.exp(-x))
    
    return s(13 * (-e + middle) / np.abs(end - start)) * np.abs(lr_start - lr_end) + lr_end

xs = np.linspace(0, 100)
ys = np.vectorize(sigmoidal_decay)(xs)
plt.plot(xs, ys)
plt.show()

EPOCHS = 3                       
lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=EPOCHS))

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=4)
cvscores = []

# %%
# Run training for certain amount of epochs
from matplotlib import image
from matplotlib.pyplot import figure

for train, val in kf.split(x, y):
    x_train, x_val = x[train],x[val]
    y_train, y_val = y[train],y[val]

    model = ResNet()
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    History = model.fit(x_train,y_train, 
        validation_data = (x_val, y_val), 
        epochs = n_epochs,  verbose=1, class_weight = class_weight, callbacks = [lr,mc])

    plt.figure(figsize=(4, 4))
    plt.title("Learning curve")
    plt.plot(History.history["loss"], label="loss")
    plt.plot(History.history["val_loss"], label="val_loss")
    plt.plot( np.argmin(History.history["val_loss"]),
            np.min(History.history["val_loss"]),
            marker="x", color="r", label="best model")

    plt.xlabel("Epochs")
    plt.ylabel("Loss Value")
    plt.legend()
    plt.show()

    figure

    plt.figure(figsize=(4, 4))
    plt.title("Accuracy")
    plt.plot(History.history["accuracy"], label="accuracy")
    plt.plot(History.history["val_accuracy"], label="val_accuracy")
    plt.plot( np.argmax(History.history["val_accuracy"]),
            np.max(History.history["val_accuracy"]),
            marker="x", color="r", label="best model")

    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()
    
    # evaluate the model
    scores = model.evaluate(x_val, y_val, verbose=1)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    
    print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Epoch 1/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.8891 - accuracy: 0.4403WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 6s 31ms/step - loss: 2.8850 - accuracy: 0.4416 - val_loss: 2.3678 - val_accuracy: 0.3800 - lr: 9.9851e-04
# Epoch 2/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.4163 - accuracy: 0.5455WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.4138 - accuracy: 0.5462 - val_loss: 2.4798 - val_accuracy: 0.3800 - lr: 8.9824e-04
# Epoch 3/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2487 - accuracy: 0.5741WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2456 - accuracy: 0.5758 - val_loss: 2.1227 - val_accuracy: 0.3800 - lr: 1.1176e-04
# Epoch 4/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2303 - accuracy: 0.5843WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2299 - accuracy: 0.5845 - val_loss: 1.8238 - val_accuracy: 0.4211 - lr: 1.1486e-05
# Epoch 5/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2265 - accuracy: 0.5884WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2252 - accuracy: 0.5884 - val_loss: 1.5380 - val_accuracy: 0.5680 - lr: 1.0000e-05
# Epoch 6/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2184 - accuracy: 0.5853WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2183 - accuracy: 0.5852 - val_loss: 1.4519 - val_accuracy: 0.6861 - lr: 1.0000e-05
# Epoch 7/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2226 - accuracy: 0.5813WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2212 - accuracy: 0.5811 - val_loss: 1.4496 - val_accuracy: 0.6861 - lr: 1.0000e-05
# Epoch 8/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2240 - accuracy: 0.5843WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2211 - accuracy: 0.5848 - val_loss: 1.4285 - val_accuracy: 0.6688 - lr: 1.0000e-05
# Epoch 9/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2209 - accuracy: 0.5817WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2207 - accuracy: 0.5818 - val_loss: 1.4319 - val_accuracy: 0.6746 - lr: 1.0000e-05
# Epoch 10/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2142 - accuracy: 0.5877WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2159 - accuracy: 0.5884 - val_loss: 1.4042 - val_accuracy: 0.6463 - lr: 1.0000e-05
# Epoch 11/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2119 - accuracy: 0.5942WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2122 - accuracy: 0.5940 - val_loss: 1.4501 - val_accuracy: 0.6919 - lr: 1.0000e-05
# Epoch 12/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2125 - accuracy: 0.5886WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2122 - accuracy: 0.5893 - val_loss: 1.4030 - val_accuracy: 0.6656 - lr: 1.0000e-05
# Epoch 13/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2055 - accuracy: 0.5864WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2046 - accuracy: 0.5863 - val_loss: 1.4476 - val_accuracy: 0.6983 - lr: 1.0000e-05
# Epoch 14/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1997 - accuracy: 0.5935WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 31ms/step - loss: 2.1984 - accuracy: 0.5931 - val_loss: 1.4218 - val_accuracy: 0.6868 - lr: 1.0000e-05
# Epoch 15/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1927 - accuracy: 0.5881WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1955 - accuracy: 0.5871 - val_loss: 1.4204 - val_accuracy: 0.6797 - lr: 1.0000e-05
# Epoch 16/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1963 - accuracy: 0.5894WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1949 - accuracy: 0.5901 - val_loss: 1.4143 - val_accuracy: 0.6804 - lr: 1.0000e-05
# Epoch 17/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1967 - accuracy: 0.5903WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1960 - accuracy: 0.5899 - val_loss: 1.3944 - val_accuracy: 0.6598 - lr: 1.0000e-05
# Epoch 18/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1875 - accuracy: 0.5929WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1874 - accuracy: 0.5927 - val_loss: 1.4041 - val_accuracy: 0.6759 - lr: 1.0000e-05
# Epoch 19/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1707 - accuracy: 0.6011WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1735 - accuracy: 0.6006 - val_loss: 1.3900 - val_accuracy: 0.6470 - lr: 1.0000e-05
# Epoch 20/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1910 - accuracy: 0.5925WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1891 - accuracy: 0.5927 - val_loss: 1.4116 - val_accuracy: 0.6932 - lr: 1.0000e-05
# Epoch 21/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1765 - accuracy: 0.6041WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1843 - accuracy: 0.6027 - val_loss: 1.4001 - val_accuracy: 0.6784 - lr: 1.0000e-05
# Epoch 22/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1772 - accuracy: 0.6013WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1788 - accuracy: 0.6010 - val_loss: 1.3846 - val_accuracy: 0.6733 - lr: 1.0000e-05
# Epoch 23/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1780 - accuracy: 0.5909WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1817 - accuracy: 0.5903 - val_loss: 1.4090 - val_accuracy: 0.6849 - lr: 1.0000e-05
# Epoch 24/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1771 - accuracy: 0.5966WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1781 - accuracy: 0.5965 - val_loss: 1.3764 - val_accuracy: 0.6566 - lr: 1.0000e-05
# Epoch 25/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1623 - accuracy: 0.5981WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1587 - accuracy: 0.5985 - val_loss: 1.3958 - val_accuracy: 0.6849 - lr: 1.0000e-05
# Epoch 26/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1802 - accuracy: 0.5991WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1813 - accuracy: 0.5989 - val_loss: 1.3804 - val_accuracy: 0.6701 - lr: 1.0000e-05
# Epoch 27/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1791 - accuracy: 0.5955WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1763 - accuracy: 0.5963 - val_loss: 1.3945 - val_accuracy: 0.6964 - lr: 1.0000e-05
# Epoch 28/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1598 - accuracy: 0.5978WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1617 - accuracy: 0.5970 - val_loss: 1.3916 - val_accuracy: 0.6893 - lr: 1.0000e-05
# Epoch 29/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1580 - accuracy: 0.5989WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1586 - accuracy: 0.5987 - val_loss: 1.3716 - val_accuracy: 0.6772 - lr: 1.0000e-05
# Epoch 30/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1631 - accuracy: 0.5976WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 5s 31ms/step - loss: 2.1614 - accuracy: 0.5982 - val_loss: 1.3743 - val_accuracy: 0.6791 - lr: 1.0000e-05
# Epoch 31/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1466 - accuracy: 0.6028WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1525 - accuracy: 0.6021 - val_loss: 1.3975 - val_accuracy: 0.6868 - lr: 1.0000e-05
# Epoch 32/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1480 - accuracy: 0.6030WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1496 - accuracy: 0.6027 - val_loss: 1.3716 - val_accuracy: 0.6714 - lr: 1.0000e-05
# Epoch 33/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1642 - accuracy: 0.6009WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1652 - accuracy: 0.6006 - val_loss: 1.3774 - val_accuracy: 0.6752 - lr: 1.0000e-05
# Epoch 34/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1497 - accuracy: 0.6062WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 31ms/step - loss: 2.1468 - accuracy: 0.6072 - val_loss: 1.3601 - val_accuracy: 0.6643 - lr: 1.0000e-05
# Epoch 35/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1512 - accuracy: 0.6060WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1504 - accuracy: 0.6066 - val_loss: 1.3880 - val_accuracy: 0.7144 - lr: 1.0000e-05
# Epoch 36/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1382 - accuracy: 0.6103WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1381 - accuracy: 0.6100 - val_loss: 1.3607 - val_accuracy: 0.6739 - lr: 1.0000e-05
# Epoch 37/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1465 - accuracy: 0.6123WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1465 - accuracy: 0.6128 - val_loss: 1.3650 - val_accuracy: 0.6990 - lr: 1.0000e-05
# Epoch 38/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1318 - accuracy: 0.6045WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1341 - accuracy: 0.6045 - val_loss: 1.3579 - val_accuracy: 0.6765 - lr: 1.0000e-05
# Epoch 39/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1301 - accuracy: 0.6129WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1331 - accuracy: 0.6122 - val_loss: 1.3589 - val_accuracy: 0.6804 - lr: 1.0000e-05
# Epoch 40/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1332 - accuracy: 0.6062WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1344 - accuracy: 0.6060 - val_loss: 1.4060 - val_accuracy: 0.7323 - lr: 1.0000e-05
# Epoch 41/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1276 - accuracy: 0.6138WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1310 - accuracy: 0.6128 - val_loss: 1.3768 - val_accuracy: 0.7208 - lr: 1.0000e-05
# Epoch 42/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1254 - accuracy: 0.6153WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1298 - accuracy: 0.6143 - val_loss: 1.3629 - val_accuracy: 0.6829 - lr: 1.0000e-05
# Epoch 43/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1263 - accuracy: 0.6103WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1297 - accuracy: 0.6100 - val_loss: 1.3737 - val_accuracy: 0.6958 - lr: 1.0000e-05
# Epoch 44/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1266 - accuracy: 0.6095WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1270 - accuracy: 0.6100 - val_loss: 1.3554 - val_accuracy: 0.7015 - lr: 1.0000e-05
# Epoch 45/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1158 - accuracy: 0.6056WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1179 - accuracy: 0.6057 - val_loss: 1.3580 - val_accuracy: 0.7092 - lr: 1.0000e-05
# Epoch 46/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1351 - accuracy: 0.6129WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1308 - accuracy: 0.6143 - val_loss: 1.3468 - val_accuracy: 0.6836 - lr: 1.0000e-05
# Epoch 47/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1094 - accuracy: 0.6134WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1093 - accuracy: 0.6139 - val_loss: 1.3706 - val_accuracy: 0.7176 - lr: 1.0000e-05
# Epoch 48/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1359 - accuracy: 0.6039WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1365 - accuracy: 0.6040 - val_loss: 1.3487 - val_accuracy: 0.7022 - lr: 1.0000e-05
# Epoch 49/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1160 - accuracy: 0.6153WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1149 - accuracy: 0.6158 - val_loss: 1.3364 - val_accuracy: 0.6919 - lr: 1.0000e-05
# Epoch 50/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1300 - accuracy: 0.6060WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1285 - accuracy: 0.6062 - val_loss: 1.3336 - val_accuracy: 0.7067 - lr: 1.0000e-05
# Epoch 51/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1225 - accuracy: 0.6153WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1227 - accuracy: 0.6154 - val_loss: 1.3275 - val_accuracy: 0.6816 - lr: 1.0000e-05
# Epoch 52/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1136 - accuracy: 0.6179WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 31ms/step - loss: 2.1136 - accuracy: 0.6182 - val_loss: 1.3615 - val_accuracy: 0.7144 - lr: 1.0000e-05
# Epoch 53/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1176 - accuracy: 0.6166WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1152 - accuracy: 0.6173 - val_loss: 1.3262 - val_accuracy: 0.6778 - lr: 1.0000e-05
# Epoch 54/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1015 - accuracy: 0.6153WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1014 - accuracy: 0.6152 - val_loss: 1.3298 - val_accuracy: 0.6983 - lr: 1.0000e-05
# Epoch 55/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1118 - accuracy: 0.6058WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1111 - accuracy: 0.6064 - val_loss: 1.3317 - val_accuracy: 0.7028 - lr: 1.0000e-05
# Epoch 56/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1042 - accuracy: 0.6065WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1037 - accuracy: 0.6068 - val_loss: 1.3379 - val_accuracy: 0.7035 - lr: 1.0000e-05
# Epoch 57/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1017 - accuracy: 0.6075WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1055 - accuracy: 0.6072 - val_loss: 1.3340 - val_accuracy: 0.7067 - lr: 1.0000e-05
# Epoch 58/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1079 - accuracy: 0.6144WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 5s 31ms/step - loss: 2.1046 - accuracy: 0.6152 - val_loss: 1.3294 - val_accuracy: 0.7015 - lr: 1.0000e-05
# Epoch 59/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0965 - accuracy: 0.6200WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0996 - accuracy: 0.6192 - val_loss: 1.3579 - val_accuracy: 0.7471 - lr: 1.0000e-05
# Epoch 60/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0970 - accuracy: 0.6110WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.0974 - accuracy: 0.6109 - val_loss: 1.3325 - val_accuracy: 0.7272 - lr: 1.0000e-05
# Epoch 61/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0861 - accuracy: 0.6213WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0872 - accuracy: 0.6205 - val_loss: 1.3279 - val_accuracy: 0.7080 - lr: 1.0000e-05
# Epoch 62/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1020 - accuracy: 0.6140WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1003 - accuracy: 0.6137 - val_loss: 1.3462 - val_accuracy: 0.7118 - lr: 1.0000e-05
# Epoch 63/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0969 - accuracy: 0.6196WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1018 - accuracy: 0.6186 - val_loss: 1.3174 - val_accuracy: 0.7092 - lr: 1.0000e-05
# Epoch 64/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0911 - accuracy: 0.6155WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0908 - accuracy: 0.6160 - val_loss: 1.3621 - val_accuracy: 0.7458 - lr: 1.0000e-05
# Epoch 65/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0882 - accuracy: 0.6159WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.0864 - accuracy: 0.6162 - val_loss: 1.3354 - val_accuracy: 0.7054 - lr: 1.0000e-05
# Epoch 66/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1059 - accuracy: 0.6088WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1048 - accuracy: 0.6089 - val_loss: 1.3234 - val_accuracy: 0.7195 - lr: 1.0000e-05
# Epoch 67/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0863 - accuracy: 0.6123WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0881 - accuracy: 0.6119 - val_loss: 1.3103 - val_accuracy: 0.6893 - lr: 1.0000e-05
# Epoch 68/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0751 - accuracy: 0.6233WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.0743 - accuracy: 0.6239 - val_loss: 1.3037 - val_accuracy: 0.6791 - lr: 1.0000e-05
# Epoch 69/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0878 - accuracy: 0.6222WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.0864 - accuracy: 0.6220 - val_loss: 1.3266 - val_accuracy: 0.7420 - lr: 1.0000e-05
# Epoch 70/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0791 - accuracy: 0.6211WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0775 - accuracy: 0.6216 - val_loss: 1.3399 - val_accuracy: 0.7587 - lr: 1.0000e-05
# Epoch 71/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0767 - accuracy: 0.6228WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0778 - accuracy: 0.6218 - val_loss: 1.3028 - val_accuracy: 0.7015 - lr: 1.0000e-05
# Epoch 72/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0835 - accuracy: 0.6248WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.0831 - accuracy: 0.6246 - val_loss: 1.2966 - val_accuracy: 0.6810 - lr: 1.0000e-05
# Epoch 73/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0845 - accuracy: 0.6284WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0856 - accuracy: 0.6282 - val_loss: 1.3621 - val_accuracy: 0.7734 - lr: 1.0000e-05
# Epoch 74/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0650 - accuracy: 0.6300WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.0641 - accuracy: 0.6299 - val_loss: 1.3060 - val_accuracy: 0.7266 - lr: 1.0000e-05
# Epoch 75/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0695 - accuracy: 0.6237WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0731 - accuracy: 0.6233 - val_loss: 1.3323 - val_accuracy: 0.7522 - lr: 1.0000e-05
# Epoch 76/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0616 - accuracy: 0.6256WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 5s 31ms/step - loss: 2.0667 - accuracy: 0.6252 - val_loss: 1.2938 - val_accuracy: 0.6945 - lr: 1.0000e-05
# Epoch 77/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0626 - accuracy: 0.6226WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0639 - accuracy: 0.6224 - val_loss: 1.3024 - val_accuracy: 0.7067 - lr: 1.0000e-05
# Epoch 78/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0717 - accuracy: 0.6317WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.0723 - accuracy: 0.6321 - val_loss: 1.3134 - val_accuracy: 0.7535 - lr: 1.0000e-05
# Epoch 79/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0702 - accuracy: 0.6304WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.0690 - accuracy: 0.6304 - val_loss: 1.3260 - val_accuracy: 0.7529 - lr: 1.0000e-05
# Epoch 80/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.0649 - accuracy: 0.6321WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.0641 - accuracy: 0.6327 - val_loss: 1.3149 - val_accuracy: 0.7529 - lr: 1.0000e-05
# 49/49 [==============================] - 1s 10ms/step - loss: 1.3149 - accuracy: 0.7529
# accuracy: 75.29%
# 75.29% (+/- 0.00%)
# Epoch 1/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.8700 - accuracy: 0.4612WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 5s 31ms/step - loss: 2.8669 - accuracy: 0.4619 - val_loss: 2.3423 - val_accuracy: 0.3999 - lr: 9.9851e-04
# Epoch 2/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.5011 - accuracy: 0.5392WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.4981 - accuracy: 0.5392 - val_loss: 2.4327 - val_accuracy: 0.3999 - lr: 8.9824e-04
# Epoch 3/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3542 - accuracy: 0.5578WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.3539 - accuracy: 0.5578 - val_loss: 2.4053 - val_accuracy: 0.4005 - lr: 1.1176e-04
# Epoch 4/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3424 - accuracy: 0.5608WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.3401 - accuracy: 0.5616 - val_loss: 1.9817 - val_accuracy: 0.4185 - lr: 1.1486e-05
# Epoch 5/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3266 - accuracy: 0.5657WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.3294 - accuracy: 0.5657 - val_loss: 1.5829 - val_accuracy: 0.5347 - lr: 1.0000e-05
# Epoch 6/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3218 - accuracy: 0.5739WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.3207 - accuracy: 0.5738 - val_loss: 1.5067 - val_accuracy: 0.6297 - lr: 1.0000e-05
# Epoch 7/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3135 - accuracy: 0.5763WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.3147 - accuracy: 0.5756 - val_loss: 1.4881 - val_accuracy: 0.6335 - lr: 1.0000e-05
# Epoch 8/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3208 - accuracy: 0.5692WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.3196 - accuracy: 0.5691 - val_loss: 1.4949 - val_accuracy: 0.6367 - lr: 1.0000e-05
# Epoch 9/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3059 - accuracy: 0.5836WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.3076 - accuracy: 0.5830 - val_loss: 1.5120 - val_accuracy: 0.6374 - lr: 1.0000e-05
# Epoch 10/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3155 - accuracy: 0.5726WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.3138 - accuracy: 0.5730 - val_loss: 1.4725 - val_accuracy: 0.6348 - lr: 1.0000e-05
# Epoch 11/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3076 - accuracy: 0.5731WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.3076 - accuracy: 0.5732 - val_loss: 1.4737 - val_accuracy: 0.6399 - lr: 1.0000e-05
# Epoch 12/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3098 - accuracy: 0.5752WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.3094 - accuracy: 0.5747 - val_loss: 1.4707 - val_accuracy: 0.6374 - lr: 1.0000e-05
# Epoch 13/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3159 - accuracy: 0.5767WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.3148 - accuracy: 0.5773 - val_loss: 1.4749 - val_accuracy: 0.6380 - lr: 1.0000e-05
# Epoch 14/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.3037 - accuracy: 0.5808WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.3054 - accuracy: 0.5813 - val_loss: 1.4772 - val_accuracy: 0.6412 - lr: 1.0000e-05
# Epoch 15/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2990 - accuracy: 0.5881WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 5s 31ms/step - loss: 2.2961 - accuracy: 0.5884 - val_loss: 1.4673 - val_accuracy: 0.6438 - lr: 1.0000e-05
# Epoch 16/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2916 - accuracy: 0.5832WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2910 - accuracy: 0.5822 - val_loss: 1.4703 - val_accuracy: 0.6425 - lr: 1.0000e-05
# Epoch 17/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2925 - accuracy: 0.5841WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2922 - accuracy: 0.5837 - val_loss: 1.4860 - val_accuracy: 0.6451 - lr: 1.0000e-05
# Epoch 18/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2955 - accuracy: 0.5772WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2960 - accuracy: 0.5773 - val_loss: 1.4595 - val_accuracy: 0.6444 - lr: 1.0000e-05
# Epoch 19/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2896 - accuracy: 0.5825WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2933 - accuracy: 0.5818 - val_loss: 1.4686 - val_accuracy: 0.6451 - lr: 1.0000e-05
# Epoch 20/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2795 - accuracy: 0.5817WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2820 - accuracy: 0.5818 - val_loss: 1.4537 - val_accuracy: 0.6451 - lr: 1.0000e-05
# Epoch 21/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2781 - accuracy: 0.5830WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2776 - accuracy: 0.5830 - val_loss: 1.4611 - val_accuracy: 0.6457 - lr: 1.0000e-05
# Epoch 22/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2721 - accuracy: 0.5832WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2735 - accuracy: 0.5837 - val_loss: 1.4752 - val_accuracy: 0.6489 - lr: 1.0000e-05
# Epoch 23/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2699 - accuracy: 0.5858WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2694 - accuracy: 0.5858 - val_loss: 1.4449 - val_accuracy: 0.6489 - lr: 1.0000e-05
# Epoch 24/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2657 - accuracy: 0.5886WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 5s 31ms/step - loss: 2.2659 - accuracy: 0.5875 - val_loss: 1.4416 - val_accuracy: 0.6463 - lr: 1.0000e-05
# Epoch 25/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2765 - accuracy: 0.5834WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2792 - accuracy: 0.5833 - val_loss: 1.4554 - val_accuracy: 0.6502 - lr: 1.0000e-05
# Epoch 26/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2659 - accuracy: 0.5875WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2649 - accuracy: 0.5882 - val_loss: 1.4647 - val_accuracy: 0.6528 - lr: 1.0000e-05
# Epoch 27/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2688 - accuracy: 0.5918WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2675 - accuracy: 0.5916 - val_loss: 1.4616 - val_accuracy: 0.6579 - lr: 1.0000e-05
# Epoch 28/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2666 - accuracy: 0.5935WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2690 - accuracy: 0.5935 - val_loss: 1.4330 - val_accuracy: 0.6508 - lr: 1.0000e-05
# Epoch 29/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2670 - accuracy: 0.5940WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2706 - accuracy: 0.5925 - val_loss: 1.4439 - val_accuracy: 0.6540 - lr: 1.0000e-05
# Epoch 30/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2573 - accuracy: 0.5858WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2575 - accuracy: 0.5852 - val_loss: 1.4562 - val_accuracy: 0.6573 - lr: 1.0000e-05
# Epoch 31/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2494 - accuracy: 0.5929WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2540 - accuracy: 0.5923 - val_loss: 1.4254 - val_accuracy: 0.6540 - lr: 1.0000e-05
# Epoch 32/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2655 - accuracy: 0.5877WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2654 - accuracy: 0.5871 - val_loss: 1.4445 - val_accuracy: 0.6560 - lr: 1.0000e-05
# Epoch 33/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2566 - accuracy: 0.5886WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2591 - accuracy: 0.5882 - val_loss: 1.4268 - val_accuracy: 0.6566 - lr: 1.0000e-05
# Epoch 34/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2438 - accuracy: 0.5972WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 5s 31ms/step - loss: 2.2447 - accuracy: 0.5970 - val_loss: 1.4163 - val_accuracy: 0.6534 - lr: 1.0000e-05
# Epoch 35/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2449 - accuracy: 0.5959WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2441 - accuracy: 0.5952 - val_loss: 1.4182 - val_accuracy: 0.6566 - lr: 1.0000e-05
# Epoch 36/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2483 - accuracy: 0.5955WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2489 - accuracy: 0.5948 - val_loss: 1.4244 - val_accuracy: 0.6573 - lr: 1.0000e-05
# Epoch 37/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2398 - accuracy: 0.5963WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2431 - accuracy: 0.5955 - val_loss: 1.4216 - val_accuracy: 0.6579 - lr: 1.0000e-05
# Epoch 38/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2336 - accuracy: 0.5963WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2334 - accuracy: 0.5972 - val_loss: 1.4270 - val_accuracy: 0.6592 - lr: 1.0000e-05
# Epoch 39/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2254 - accuracy: 0.5983WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2245 - accuracy: 0.5980 - val_loss: 1.4262 - val_accuracy: 0.6605 - lr: 1.0000e-05
# Epoch 40/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2363 - accuracy: 0.5897WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 31ms/step - loss: 2.2382 - accuracy: 0.5897 - val_loss: 1.4110 - val_accuracy: 0.6573 - lr: 1.0000e-05
# Epoch 41/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2246 - accuracy: 0.5935WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2226 - accuracy: 0.5935 - val_loss: 1.4227 - val_accuracy: 0.6624 - lr: 1.0000e-05
# Epoch 42/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2300 - accuracy: 0.5994WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2318 - accuracy: 0.5985 - val_loss: 1.4145 - val_accuracy: 0.6662 - lr: 1.0000e-05
# Epoch 43/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2255 - accuracy: 0.6045WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2251 - accuracy: 0.6049 - val_loss: 1.3990 - val_accuracy: 0.6592 - lr: 1.0000e-05
# Epoch 44/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2234 - accuracy: 0.5955WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2224 - accuracy: 0.5955 - val_loss: 1.4154 - val_accuracy: 0.6656 - lr: 1.0000e-05
# Epoch 45/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2208 - accuracy: 0.5983WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2191 - accuracy: 0.5982 - val_loss: 1.3868 - val_accuracy: 0.6611 - lr: 1.0000e-05
# Epoch 46/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2059 - accuracy: 0.6058WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2073 - accuracy: 0.6051 - val_loss: 1.4058 - val_accuracy: 0.6656 - lr: 1.0000e-05
# Epoch 47/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2173 - accuracy: 0.5970WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2200 - accuracy: 0.5967 - val_loss: 1.4297 - val_accuracy: 0.6701 - lr: 1.0000e-05
# Epoch 48/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2244 - accuracy: 0.6011WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2233 - accuracy: 0.6008 - val_loss: 1.3841 - val_accuracy: 0.6630 - lr: 1.0000e-05
# Epoch 49/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2114 - accuracy: 0.5978WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.2122 - accuracy: 0.5976 - val_loss: 1.3801 - val_accuracy: 0.6650 - lr: 1.0000e-05
# Epoch 50/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1981 - accuracy: 0.6037WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1985 - accuracy: 0.6042 - val_loss: 1.4062 - val_accuracy: 0.6694 - lr: 1.0000e-05
# Epoch 51/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1964 - accuracy: 0.6108WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1992 - accuracy: 0.6098 - val_loss: 1.3841 - val_accuracy: 0.6688 - lr: 1.0000e-05
# Epoch 52/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.2010 - accuracy: 0.6082WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.2027 - accuracy: 0.6077 - val_loss: 1.3733 - val_accuracy: 0.6643 - lr: 1.0000e-05
# Epoch 53/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1961 - accuracy: 0.6028WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1979 - accuracy: 0.6021 - val_loss: 1.3835 - val_accuracy: 0.6727 - lr: 1.0000e-05
# Epoch 54/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1932 - accuracy: 0.6121WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1909 - accuracy: 0.6119 - val_loss: 1.3961 - val_accuracy: 0.6739 - lr: 1.0000e-05
# Epoch 55/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1928 - accuracy: 0.6069WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1921 - accuracy: 0.6077 - val_loss: 1.3770 - val_accuracy: 0.6746 - lr: 1.0000e-05
# Epoch 56/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1885 - accuracy: 0.6144WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1865 - accuracy: 0.6152 - val_loss: 1.3878 - val_accuracy: 0.6784 - lr: 1.0000e-05
# Epoch 57/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1967 - accuracy: 0.6108WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1930 - accuracy: 0.6119 - val_loss: 1.3781 - val_accuracy: 0.6727 - lr: 1.0000e-05
# Epoch 58/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1870 - accuracy: 0.6140WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1856 - accuracy: 0.6145 - val_loss: 1.3827 - val_accuracy: 0.6784 - lr: 1.0000e-05
# Epoch 59/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1999 - accuracy: 0.6037WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1999 - accuracy: 0.6032 - val_loss: 1.3566 - val_accuracy: 0.6739 - lr: 1.0000e-05
# Epoch 60/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1990 - accuracy: 0.6032WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1984 - accuracy: 0.6030 - val_loss: 1.3435 - val_accuracy: 0.6701 - lr: 1.0000e-05
# Epoch 61/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1955 - accuracy: 0.6006WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1957 - accuracy: 0.5997 - val_loss: 1.3623 - val_accuracy: 0.6759 - lr: 1.0000e-05
# Epoch 62/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1762 - accuracy: 0.6095WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1792 - accuracy: 0.6085 - val_loss: 1.3590 - val_accuracy: 0.6746 - lr: 1.0000e-05
# Epoch 63/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1780 - accuracy: 0.6060WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1763 - accuracy: 0.6057 - val_loss: 1.3679 - val_accuracy: 0.6816 - lr: 1.0000e-05
# Epoch 64/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1619 - accuracy: 0.6170WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1636 - accuracy: 0.6169 - val_loss: 1.3724 - val_accuracy: 0.6868 - lr: 1.0000e-05
# Epoch 65/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1747 - accuracy: 0.6168WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 29ms/step - loss: 2.1747 - accuracy: 0.6164 - val_loss: 1.3390 - val_accuracy: 0.6739 - lr: 1.0000e-05
# Epoch 66/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1659 - accuracy: 0.6151WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1675 - accuracy: 0.6154 - val_loss: 1.3699 - val_accuracy: 0.6849 - lr: 1.0000e-05
# Epoch 67/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1642 - accuracy: 0.6172WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1668 - accuracy: 0.6169 - val_loss: 1.3610 - val_accuracy: 0.6855 - lr: 1.0000e-05
# Epoch 68/80
# 145/146 [============================>.] - ETA: 0s - loss: 2.1636 - accuracy: 0.6185WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 146/146 [==============================] - 4s 30ms/step - loss: 2.1638 - accuracy: 0.6190 - val_loss: 1.3632 - val_accuracy: 0.6849 - lr: 1.0000e-05
# Epoch 69/80
# ...
# Epoch 32/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0789 - accuracy: 0.6119WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0806 - accuracy: 0.6107 - val_loss: 1.5746 - val_accuracy: 0.5286 - lr: 1.0000e-05
# Epoch 33/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0701 - accuracy: 0.6065WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0712 - accuracy: 0.6058 - val_loss: 1.5816 - val_accuracy: 0.5337 - lr: 1.0000e-05
# Epoch 34/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0894 - accuracy: 0.5996WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0871 - accuracy: 0.6000 - val_loss: 1.5692 - val_accuracy: 0.5279 - lr: 1.0000e-05
# Epoch 35/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0818 - accuracy: 0.6015WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0800 - accuracy: 0.6018 - val_loss: 1.5822 - val_accuracy: 0.5472 - lr: 1.0000e-05
# Epoch 36/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0732 - accuracy: 0.6065WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0732 - accuracy: 0.6069 - val_loss: 1.5725 - val_accuracy: 0.5324 - lr: 1.0000e-05
# Epoch 37/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0764 - accuracy: 0.6052WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0759 - accuracy: 0.6048 - val_loss: 1.5626 - val_accuracy: 0.5286 - lr: 1.0000e-05
# Epoch 38/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0751 - accuracy: 0.6019WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0763 - accuracy: 0.6005 - val_loss: 1.5645 - val_accuracy: 0.5260 - lr: 1.0000e-05
# Epoch 39/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0745 - accuracy: 0.6080WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0727 - accuracy: 0.6084 - val_loss: 1.5602 - val_accuracy: 0.5279 - lr: 1.0000e-05
# Epoch 40/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0673 - accuracy: 0.6039WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0660 - accuracy: 0.6043 - val_loss: 1.5604 - val_accuracy: 0.5382 - lr: 1.0000e-05
# Epoch 41/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0772 - accuracy: 0.6032WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0806 - accuracy: 0.6026 - val_loss: 1.5623 - val_accuracy: 0.5389 - lr: 1.0000e-05
# Epoch 42/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0604 - accuracy: 0.6110WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0626 - accuracy: 0.6114 - val_loss: 1.5649 - val_accuracy: 0.5401 - lr: 1.0000e-05
# Epoch 43/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0620 - accuracy: 0.5989WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0655 - accuracy: 0.5979 - val_loss: 1.5567 - val_accuracy: 0.5318 - lr: 1.0000e-05
# Epoch 44/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0649 - accuracy: 0.6071WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0637 - accuracy: 0.6075 - val_loss: 1.5612 - val_accuracy: 0.5466 - lr: 1.0000e-05
# Epoch 45/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0608 - accuracy: 0.6082WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 5s 31ms/step - loss: 2.0617 - accuracy: 0.6080 - val_loss: 1.5620 - val_accuracy: 0.5478 - lr: 1.0000e-05
# Epoch 46/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0522 - accuracy: 0.6123WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0519 - accuracy: 0.6122 - val_loss: 1.5525 - val_accuracy: 0.5414 - lr: 1.0000e-05
# Epoch 47/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0350 - accuracy: 0.6187WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0373 - accuracy: 0.6182 - val_loss: 1.5534 - val_accuracy: 0.5440 - lr: 1.0000e-05
# Epoch 48/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0537 - accuracy: 0.6131WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0543 - accuracy: 0.6131 - val_loss: 1.5463 - val_accuracy: 0.5318 - lr: 1.0000e-05
# Epoch 49/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0479 - accuracy: 0.6129WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0480 - accuracy: 0.6129 - val_loss: 1.5568 - val_accuracy: 0.5498 - lr: 1.0000e-05
# Epoch 50/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0413 - accuracy: 0.6168WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0464 - accuracy: 0.6163 - val_loss: 1.5399 - val_accuracy: 0.5286 - lr: 1.0000e-05
# Epoch 51/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0496 - accuracy: 0.6112WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0510 - accuracy: 0.6110 - val_loss: 1.5442 - val_accuracy: 0.5363 - lr: 1.0000e-05
# Epoch 52/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0425 - accuracy: 0.6168WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 29ms/step - loss: 2.0428 - accuracy: 0.6167 - val_loss: 1.5547 - val_accuracy: 0.5523 - lr: 1.0000e-05
# Epoch 53/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0437 - accuracy: 0.6162WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0415 - accuracy: 0.6165 - val_loss: 1.5455 - val_accuracy: 0.5485 - lr: 1.0000e-05
# Epoch 54/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0317 - accuracy: 0.6101WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0316 - accuracy: 0.6099 - val_loss: 1.5443 - val_accuracy: 0.5478 - lr: 1.0000e-05
# Epoch 55/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0444 - accuracy: 0.6183WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0465 - accuracy: 0.6178 - val_loss: 1.5409 - val_accuracy: 0.5466 - lr: 1.0000e-05
# Epoch 56/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0342 - accuracy: 0.6136WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0337 - accuracy: 0.6135 - val_loss: 1.5377 - val_accuracy: 0.5376 - lr: 1.0000e-05
# Epoch 57/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0311 - accuracy: 0.6235WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 29ms/step - loss: 2.0287 - accuracy: 0.6240 - val_loss: 1.5466 - val_accuracy: 0.5523 - lr: 1.0000e-05
# Epoch 58/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0342 - accuracy: 0.6134WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0331 - accuracy: 0.6144 - val_loss: 1.5436 - val_accuracy: 0.5562 - lr: 1.0000e-05
# Epoch 59/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0333 - accuracy: 0.6231WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0335 - accuracy: 0.6221 - val_loss: 1.5307 - val_accuracy: 0.5337 - lr: 1.0000e-05
# Epoch 60/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0287 - accuracy: 0.6190WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0281 - accuracy: 0.6193 - val_loss: 1.5462 - val_accuracy: 0.5645 - lr: 1.0000e-05
# Epoch 61/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0322 - accuracy: 0.6175WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0330 - accuracy: 0.6184 - val_loss: 1.5327 - val_accuracy: 0.5485 - lr: 1.0000e-05
# Epoch 62/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0267 - accuracy: 0.6194WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0251 - accuracy: 0.6197 - val_loss: 1.5423 - val_accuracy: 0.5568 - lr: 1.0000e-05
# Epoch 63/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0129 - accuracy: 0.6220WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0173 - accuracy: 0.6212 - val_loss: 1.5374 - val_accuracy: 0.5549 - lr: 1.0000e-05
# Epoch 64/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0307 - accuracy: 0.6207WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0293 - accuracy: 0.6204 - val_loss: 1.5350 - val_accuracy: 0.5588 - lr: 1.0000e-05
# Epoch 65/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0259 - accuracy: 0.6181WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0252 - accuracy: 0.6178 - val_loss: 1.5359 - val_accuracy: 0.5594 - lr: 1.0000e-05
# Epoch 66/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0265 - accuracy: 0.6181WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0237 - accuracy: 0.6187 - val_loss: 1.5259 - val_accuracy: 0.5556 - lr: 1.0000e-05
# Epoch 67/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0090 - accuracy: 0.6211WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0107 - accuracy: 0.6208 - val_loss: 1.5219 - val_accuracy: 0.5491 - lr: 1.0000e-05
# Epoch 68/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0227 - accuracy: 0.6261WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0225 - accuracy: 0.6259 - val_loss: 1.5225 - val_accuracy: 0.5536 - lr: 1.0000e-05
# Epoch 69/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0131 - accuracy: 0.6228WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 29ms/step - loss: 2.0162 - accuracy: 0.6221 - val_loss: 1.5255 - val_accuracy: 0.5562 - lr: 1.0000e-05
# Epoch 70/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0141 - accuracy: 0.6235WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0126 - accuracy: 0.6244 - val_loss: 1.5215 - val_accuracy: 0.5588 - lr: 1.0000e-05
# Epoch 71/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0198 - accuracy: 0.6203WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0219 - accuracy: 0.6193 - val_loss: 1.5313 - val_accuracy: 0.5658 - lr: 1.0000e-05
# Epoch 72/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0103 - accuracy: 0.6216WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0139 - accuracy: 0.6217 - val_loss: 1.5225 - val_accuracy: 0.5626 - lr: 1.0000e-05
# Epoch 73/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0017 - accuracy: 0.6259WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0060 - accuracy: 0.6242 - val_loss: 1.5111 - val_accuracy: 0.5434 - lr: 1.0000e-05
# Epoch 74/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0072 - accuracy: 0.6211WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0094 - accuracy: 0.6217 - val_loss: 1.5143 - val_accuracy: 0.5575 - lr: 1.0000e-05
# Epoch 75/80
# 145/147 [============================>.] - ETA: 0s - loss: 1.9961 - accuracy: 0.6218WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0012 - accuracy: 0.6208 - val_loss: 1.5137 - val_accuracy: 0.5613 - lr: 1.0000e-05
# Epoch 76/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0230 - accuracy: 0.6144WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0227 - accuracy: 0.6146 - val_loss: 1.5222 - val_accuracy: 0.5671 - lr: 1.0000e-05
# Epoch 77/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0035 - accuracy: 0.6297WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0035 - accuracy: 0.6291 - val_loss: 1.5053 - val_accuracy: 0.5401 - lr: 1.0000e-05
# Epoch 78/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0061 - accuracy: 0.6222WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0034 - accuracy: 0.6223 - val_loss: 1.5090 - val_accuracy: 0.5549 - lr: 1.0000e-05
# Epoch 79/80
# 145/147 [============================>.] - ETA: 0s - loss: 1.9956 - accuracy: 0.6231WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0000 - accuracy: 0.6221 - val_loss: 1.5161 - val_accuracy: 0.5652 - lr: 1.0000e-05
# Epoch 80/80
# 145/147 [============================>.] - ETA: 0s - loss: 2.0062 - accuracy: 0.6278WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 147/147 [==============================] - 4s 30ms/step - loss: 2.0071 - accuracy: 0.6272 - val_loss: 1.5053 - val_accuracy: 0.5434 - lr: 1.0000e-05
# 49/49 [==============================] - 1s 10ms/step - loss: 1.5053 - accuracy: 0.5434
# accuracy: 54.34%
# 67.46% (+/- 7.88%)

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
cvscores
# Out:
# [75.28883218765259, 69.51219439506531, 70.71291208267212, 54.33526039123535]
